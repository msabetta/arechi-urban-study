# %% [markdown]
# # Analisi Corridoio Verde
#
# Questo notebook esegue un'analisi della rete ecologica urbana a partire dal file GeoJSON `green_corridor.geojson`.

# %%
# %pwd
# Out:
# '/home/mario/Scrivania/arechi-urban-study/notebooks'

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import folium

# Caricamento del GeoJSON
green_corridor_path = '../data/raw/gis/green_corridor.geojson'
green_corridor = gpd.read_file(green_corridor_path)
green_corridor.head()
# Out:
#                         name        source  \
# 0  Worst‑case Green Corridor  User defined
#
#                                          description  \
# 0  Straight line from metro station to stadium to...
#
#                                         geometry
# 0  LINESTRING (14.8297 40.6318, 14.8297 40.6278)

# %%
# Placeholder per future analisi: connettività, buffer, visualizzazioni
