# %% [markdown]
# # Analisi Accessibilità ai Trasporti Pubblici
#
# Questo notebook valuta l’accessibilità ai punti di trasporto pubblico (fermate, stazioni) nella zona di studio utilizzando dati GTFS o OpenStreetMap.

# %%
import geopandas as gpd
import pandas as pd
import osmnx as ox
import matplotlib.pyplot as plt

# Caricamento dei punti di trasporto (sostituire con il percorso reale)
gtfs_path = '../data/gtfs/gtfs_feed.zip'
# Qui inserire codice per leggere il feed GTFS (es. using gtfs_kit)
# Per esempio, caricare le fermate:
# stops = pd.read_csv('stops.txt')
# Convertire in GeoDataFrame
# stops_gdf = gpd.GeoDataFrame(stops, geometry=gpd.points_from_xy(stops['stop_lon'], stops['stop_lat']))

# Placeholder per calcolo isocrono o buffer di camminata
# e visualizzazione su mappa

# Visualizza una mappa base della zona
area = gpd.read_file('../data/raw/gis/green_corridor.geojson')
area = area.to_crs(epsg=4326)
fig, ax = plt.subplots(figsize=(10,10))
area.boundary.plot(ax=ax, edgecolor='green')
ax.set_title('Area di Studio')
plt.show()

# %%
# Placeholder: calcolo isocrono con OSMnx, aggregazione degli indicatori di accessibilità, visualizzazioni interattive con Folium
