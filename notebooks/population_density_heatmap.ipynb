# %% [markdown]
# # Heatmap Densità di Popolazione
#
# Questo notebook visualizza la distribuzione della popolazione su tutta l'area urbana mediante una heatmap.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns

# Caricamento dati demografici (da sostituire con il percorso corretto)
population_data_path = '../data/processed/population_near_arechi.csv'
pop_df = pd.read_csv(population_data_path)
pop_df.head()
# Out:
#       id                 area_name  population  distance_km  density  \
# 0  65036  Castiglione del Genovesi      2560.0         9.74      NaN
#
#          lat        lon
# 0  40.725511  14.848445

# %%
# Placeholder per futuri passaggi: rasterizzazione, creazione heatmap, visualizzazione su mappa
