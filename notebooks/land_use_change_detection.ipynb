# %% [markdown]
# # Land Use Change Detection
#
# Questo notebook confronta dati di uso del suolo di diversi anni per identificare le variazioni.

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Caricamento dei dataset (sostituire i percorsi)
land_use_2020 = gpd.read_file('../data/processed/land_use_2020.geojson')
land_use_2025 = gpd.read_file('../data/processed/land_use_2025.geojson')
land_use_2020.head()
# Out:
#        land_use                                         geometry
# 0  Residenziale      POLYGON ((0 0, 0 100, 100 100, 100 0, 0 0))
# 1   Commerciale  POLYGON ((120 0, 120 80, 200 80, 200 0, 120 0))
# 2         Verde  POLYGON ((0 120, 0 200, 80 200, 80 120, 0 120))

# %%
# Placeholder: calcolo differenze, analisi statistica e visualizzazioni
